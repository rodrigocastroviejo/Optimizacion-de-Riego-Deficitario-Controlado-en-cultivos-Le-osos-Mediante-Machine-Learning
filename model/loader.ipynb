# %% [markdown]
# ### Importar los datos
#
# Importamos los datos desde los archivos .csv a DataFrames.

# %%
import pandas as pd 


df_clima = pd.read_csv(
    'data/clima_OUT.csv',
    sep=';',                    # Delimitador de columnas
    decimal=',',                # Separador decimal
    encoding='latin1',          # Codificación para caracteres especiales (Õ, Û, Ì, etc.)
    parse_dates=['date'],       # Convertir columna de fecha a datetime
    dayfirst=True  
)



df_datos_suelo1 = pd.read_csv(
    'data/Mini1_OUT.csv',
    sep=';',                    # Delimitador de columnas
    decimal=',',                # Separador decimal
    encoding='latin1',          # Codificación para caracteres especiales (Õ, Û, Ì, etc.)
    parse_dates=['date'],       # Convertir columna de fecha a datetime
    dayfirst=True  
)

# Convertir la columna 'hour' a tipo datetime combinándola con 'date'
#df_datos_suelo1['datetime'] = pd.to_datetime(df_datos_suelo1['date']) + pd.to_timedelta(df_datos_suelo1['hour'], unit='h')

df_datos_suelo2 = pd.read_csv(
    'data/Mini2_OUT.csv',
    sep=';',                    # Delimitador de columnas
    decimal=',',                # Separador decimal
    encoding='latin1',          # Codificación para caracteres especiales (Õ, Û, Ì, etc.)
    parse_dates=['date'],       # Convertir columna de fecha a datetime
    dayfirst=True  
)

# Convertir la columna 'hour' a tipo datetime combinándola con 'date'
#df_datos_suelo2['datetime'] = pd.to_datetime(df_datos_suelo2['date']) + pd.to_timedelta(df_datos_suelo2['hour'], unit='h')

df_riego = pd.read_csv(
    'data/RIEGOS ALMENDRO2024.csv',
    sep=';',                      # Delimitador de punto y coma
    decimal=',',                  # Usa coma como separador decimal
    thousands=None,               # No hay separador de miles
    parse_dates=['Inicio', 'Fin'], # Convierte estas columnas a datetime
    dayfirst=True,                # Formato de fecha día/mes/año
    dtype={
        'Programa': 'int',
        'Nombre': 'str',
        'Activación': 'int',
        'Duración': 'str',       # Lo convertiremos después a timedelta
        'Agua m³': 'float',
        'Abono 1 L': 'float',
        'Abono 2 L': 'float',
        'Abono 3 L': 'float',
        'Abono 4 L': 'float',
        'Tipo': 'str',
        'Sectores de Riego': 'int'
    }
)

# Convertir la columna 'Duración' a timedelta
df_riego['Duración'] = pd.to_timedelta(df_riego['Duración'])

display(df_clima)
display(df_datos_suelo1)
display(df_datos_suelo2)
display(df_riego)
# Out:
#       hour       date  Índice de calor  Humedad relativa  Presión de vapor  \
# 0        0 2024-02-05            1.775             96.50            7.4375
# 1        1 2024-02-05            1.275             97.00            7.1900
# 2        2 2024-02-05            0.525             97.25            6.8300
# 3        3 2024-02-05            0.400             98.00            6.7700
# 4        4 2024-02-05           -0.050             98.00            6.5650
# ...    ...        ...              ...               ...               ...
# 5411    19 2024-09-17           19.100             53.25           22.5025
# 5412    20 2024-09-17           17.025             59.50           19.8450
# 5413    21 2024-09-17           15.475             63.50           18.0425
# 5414    22 2024-09-17           14.300             68.25           16.7775
# 5415    23 2024-09-17           13.450             72.75           15.9100
#
#       Radiación solar  Temperatura  Punto de rocío  \
# ...

# %% [markdown]
# ### Juntamos los diferentes DF en uno solo
#
# El objetivo es juntar todos los datos de entrenamiento (X), los cuales estan en los DF: df_datos_suelo1, df_datos_suelo2, df_clima.
#
# df_datos_suelo1 y df_datos_suelo2 son mediciones de sensores sobre diferentes arboles que se encuentran en la misma finca, las mediciones son similares, sin embargo, diferentes ligeramente. Crearemos dos conjuntos de datos de entrenamiento, uno con df_datos_suelo1 y df_clima y otro con df_datos_suelo2 y df_clima.
#
# Voy a mostrar la media y varianza de df_datos_suelo para ver la diferencia entre ellas y posteriormente usar la que mejor resultados obtengamos.
#
# df_riego contiene la clase objetivo (y), posteriormente haremos modificaciones a tal DF para adecuarlo al formato que deseamos para procesar los datos.

# %%
import matplotlib.pyplot as plt
import numpy as np



# Seleccionar solo columnas numéricas (excluyendo datetime)
numeric_cols = X_datos_suelo1.select_dtypes(include=['number']).columns

# Calcular medias y varianzas para ambos datasets
medias1 = X_datos_suelo1[numeric_cols].mean(axis=0)
varianzas1 = X_datos_suelo1[numeric_cols].var(axis=0)

medias2 = X_datos_suelo2[numeric_cols].mean(axis=0)
varianzas2 = X_datos_suelo2[numeric_cols].var(axis=0)

# Visualizamos media y desviación para un posible posterior análisis
#display(X_datos_suelo1)
print("Medias de los datos por columnas para X_datos_suelo1:")
print("Medias", medias1)
print("\nVarianzas de los datos por columnas para X_datos_suelo1:")
print("Desviaciones\n", varianzas1)
#display(X_datos_suelo2)
print("Medias de los datos por columnas para X_datos_suelo2:")
print("Medias", medias1) 
print("\nVarianzas de los datos por columnas para X_datos_suelo2:")
print("Desviaciones", varianzas2)

#lo mostramos en forma de grafico para su mejor visualización

plt.figure(figsize=(12, 6))

# Posiciones de las barras
x = np.arange(len(numeric_cols))
width = 0.35

# Barras para X_datos_suelo1
plt.bar(x - width/2, medias1, width, label='Suelo 1', color='blue', alpha=0.7)
# Barras para X_datos_suelo2
plt.bar(x + width/2, medias2, width, label='Suelo 2', color='orange', alpha=0.7)

plt.xlabel('Variables')
plt.ylabel('Media')
plt.title('Comparación de Medias entre Suelo 1 y Suelo 2')
plt.xticks(x, numeric_cols, rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 6))

# Barras para varianzas
plt.bar(x - width/2, varianzas1, width, label='Suelo 1', color='blue', alpha=0.7)
plt.bar(x + width/2, varianzas2, width, label='Suelo 2', color='orange', alpha=0.7)

plt.xlabel('Variables')
plt.ylabel('Varianza')
plt.title('Comparación de Varianzas entre Suelo 1 y Suelo 2')
plt.xticks(x, numeric_cols, rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()


plt.figure(figsize=(12, 6))

# Calcular desviaciones estándar
std1 = np.sqrt(varianzas1)
std2 = np.sqrt(varianzas2)

plt.bar(x - width/2, medias1, width, yerr=std1, label='Suelo 1', color='blue', alpha=0.7, capsize=5)
plt.bar(x + width/2, medias2, width, yerr=std2, label='Suelo 2', color='orange', alpha=0.7, capsize=5)

plt.xlabel('Variables')
plt.ylabel('Media ± Desviación Estándar')
plt.title('Medias con Desviación Estándar: Suelo 1 vs Suelo 2')
plt.xticks(x, numeric_cols, rotation=45, ha='right')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Medias de los datos por columnas para X_datos_suelo1:
# Medias hour                                 11.527663
# Contenido volumetrico (10 cm)        19.573451
# Contenido volumetrico (20 cm)        24.659525
# Contenido volumetrico (40 cm)        30.232623
# Contenido volumetrico (60 cm)        31.954435
# Agua util                            56.971978
# Temperatura en suelo (10 cm)         18.565224
# Temperatura en suelo (20 cm)         18.222566
# Temperatura en suelo (40 cm)         18.176005
# Temperatura en suelo (60 cm)         17.399105
# Índice de calor                      15.542681
# Humedad relativa                     68.180749
# Presión de vapor                     20.532477
# Radiación solar                     192.024934
# Temperatura                          15.608716
# Punto de rocío                        8.678168
# Temperatura del bulbo húmedo         11.768648
# Velocidad del viento                  5.604723
# Racha de viento máxima                9.939578
# ...

# %% [markdown]
# ### Preprocesar los datos: Análisis y Tratamiento de valores desconocidos

# %%
from sklearn.impute import SimpleImputer # sklearn0.20 en adelante

# Primero hacemos un analisis de la cantidad de datos que faltan en cada DF por atributo y conocemos que valores toman
# Contar NaN en cada columna
print("Datos ausente en el primer conjunto de datos de entrenamiento (X_datos_suelo1) por columna:")
nan_por_columna = X_datos_suelo1.isna().sum()
print(nan_por_columna)

print("Datos ausente en el segundo conjunto de datos de entrenamiento (X_datos_suelo2) por columna:")
nan_por_columna = X_datos_suelo2.isna().sum()
print(nan_por_columna)
# Out:
# Datos ausente en el primer conjunto de datos de entrenamiento (X_datos_suelo1) por columna:
# hour                                0
# date                                0
# Contenido volumetrico (10 cm)       0
# Contenido volumetrico (20 cm)       0
# Contenido volumetrico (40 cm)       0
# Contenido volumetrico (60 cm)       0
# Agua util                           0
# Temperatura en suelo (10 cm)        0
# Temperatura en suelo (20 cm)        0
# Temperatura en suelo (40 cm)        0
# Temperatura en suelo (60 cm)        0
# Índice de calor                     0
# Humedad relativa                    0
# Presión de vapor                    0
# Radiación solar                     0
# Temperatura                         0
# Punto de rocío                      0
# Temperatura del bulbo húmedo        0
# Velocidad del viento                0
# Racha de viento máxima              0
# Dirección del viento                0
# Humectación en hoja (porcentaje)    0
# ...

# %% [markdown]
# Los datos carecen de valores nulos en ninguna columna, por lo que no necesitan una imputación de datos faltantes.
